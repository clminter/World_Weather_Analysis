# %%
# Import the dependencies.
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np

# %%
# Create a set of random latitude and longitude combinations.
lats = np.random.uniform(low=-90.000, high=90.000, size=2000)
lngs = np.random.uniform(low=-180.000, high=180.000, size=2000)
lat_lngs = zip(lats, lngs)
lat_lngs

# %%
# Add the latitudes and longitudes to a list.
coordinates = list(lat_lngs)

# %%
# Use the citipy module to determine city based on latitude and longitude.
from citipy import citipy

# %%
# Create a list for holding the cities.
cities = []
# Identify the nearest city for each latitude and longitude combination.
for coordinate in coordinates:
    city = citipy.nearest_city(coordinate[0], coordinate[1]).city_name

    # If the city is unique, then we will add it to the cities list.
    if city not in cities:
        cities.append(city)
# Print the city count to confirm sufficient count.
len(cities)
# Out:
# 754

# %%
# Import the requests library.
import requests

# Import the API key.
from config import weather_api_key

# %%
# Starting URL for Weather Map API Call.
url = "http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=" + weather_api_key

# %%
# Create an empty list to hold the weather data.
city_data = []
# Print the beginning of the logging.
print("Beginning Data Retrieval     ")
print("-----------------------------")

# Create counters.
record_count = 1
set_count = 1
# Out:
# Beginning Data Retrieval
# -----------------------------

# %%
# Loop through all the cities in the list.
for i, city in enumerate(cities):

    # Group cities in sets of 50 for logging purposes.
    if (i % 50 == 0 and i >= 50):
        set_count += 1
        record_count = 1
    # Create endpoint URL with each city.
    city_url = url + "&q=" + city.replace(" ","+")

    # Log the URL, record, and set numbers and the city.
    print(f"Processing Record {record_count} of Set {set_count} | {city}")
    # Add 1 to the record count.
    record_count += 1
    # Run an API request for each of the cities.
    try:
        # Parse the JSON and retrieve data.
        city_weather = requests.get(city_url).json()
        # Parse out the needed data.
        city_lat = city_weather['coord']['lat']
        city_lng = city_weather['coord']['lon']
        city_max_temp = city_weather['main']['temp_max']
        city_humidity = city_weather['main']['humidity']
        city_clouds = city_weather['clouds']['all']
        city_wind = city_weather['wind']['speed']
        city_country = city_weather['sys']['country']
        weather_description = city_weather["weather"][0]["description"]
        
       
        # Append the city information into city_data list.
        city_data.append(
        {  
            'City': city,
            'Lat': city_lat,
            'Lng': city_lng,
            'Max Temp': city_max_temp,
            'Humidity': city_humidity,
            'Cloudiness': city_clouds,
            'Wind Speed': city_wind,
            'Country': city_country,
            'Current Description': weather_description,
        })

# If an error is experienced, skip the city.
    except:
        print("City not found. Skipping...")
        pass

# Indicate that Data Loading is complete.
print("-----------------------------")
print("Data Retrieval Complete      ")
print("-----------------------------")
# Out:
# Processing Record 5 of Set 16 | bluff
# Processing Record 6 of Set 16 | andevoranto
# City not found. Skipping...
# Processing Record 7 of Set 16 | atuona
# Processing Record 8 of Set 16 | plouzane
# Processing Record 9 of Set 16 | port alfred
# Processing Record 10 of Set 16 | ushuaia
# Processing Record 11 of Set 16 | illoqqortoormiut
# City not found. Skipping...
# Processing Record 12 of Set 16 | punta arenas
# Processing Record 13 of Set 16 | atlantis
# Processing Record 14 of Set 16 | norman wells
# Processing Record 15 of Set 16 | severo-kurilsk
# Processing Record 16 of Set 16 | raudeberg
# Processing Record 17 of Set 16 | avera
# Processing Record 18 of Set 16 | olinda
# Processing Record 19 of Set 16 | upernavik
# Processing Record 20 of Set 16 | barentsburg
# City not found. Skipping...
# Processing Record 21 of Set 16 | zhangjiakou
# Processing Record 22 of Set 16 | mataura
# Processing Record 23 of Set 16 | amderma
# City not found. Skipping...
# Processing Record 24 of Set 16 | caravelas
# Processing Record 25 of Set 16 | lasa
# Processing Record 26 of Set 16 | albany
# Processing Record 27 of Set 16 | coquimbo
# Processing Record 28 of Set 16 | cauas
# Processing Record 29 of Set 16 | hamilton
# Processing Record 30 of Set 16 | mar del plata
# Processing Record 31 of Set 16 | thompson
# Processing Record 32 of Set 16 | springbok
# Processing Record 33 of Set 16 | sibolga
# Processing Record 34 of Set 16 | havre-saint-pierre
# Processing Record 35 of Set 16 | longyearbyen
# Processing Record 36 of Set 16 | dikson
# Processing Record 37 of Set 16 | sukumo
# Processing Record 38 of Set 16 | barrow
# Processing Record 39 of Set 16 | vaini
# Processing Record 40 of Set 16 | bethel
# Processing Record 41 of Set 16 | port hardy
# Processing Record 42 of Set 16 | taolanaro
# City not found. Skipping...
# Processing Record 43 of Set 16 | avarua
# Processing Record 44 of Set 16 | husavik
# Processing Record 45 of Set 16 | cidreira
# Processing Record 46 of Set 16 | cape town
# Processing Record 47 of Set 16 | hermanus
# Processing Record 48 of Set 16 | jamestown
# Processing Record 49 of Set 16 | hami
# Processing Record 50 of Set 16 | diego de almagro
# Processing Record 51 of Set 16 | deputatskiy
# Processing Record 52 of Set 16 | qaanaaq
# Processing Record 53 of Set 16 | yar-sale
# Processing Record 54 of Set 16 | rikitea
# Processing Record 1 of Set 17 | scottsburgh
# City not found. Skipping...
# Processing Record 2 of Set 17 | georgetown
# Processing Record 3 of Set 17 | kodiak
# Processing Record 4 of Set 17 | eydhafushi
# Processing Record 5 of Set 17 | westport
# Processing Record 6 of Set 17 | kapaa
# Processing Record 7 of Set 17 | omsukchan
# Processing Record 8 of Set 17 | gramsh
# Processing Record 9 of Set 17 | toliary
# City not found. Skipping...
# Processing Record 10 of Set 17 | svetlogorsk
# Processing Record 11 of Set 17 | grindavik
# Processing Record 12 of Set 17 | east london
# Processing Record 13 of Set 17 | busselton
# Processing Record 14 of Set 17 | cabo san lucas
# Processing Record 15 of Set 17 | griffith
# Processing Record 16 of Set 17 | butaritari
# Processing Record 17 of Set 17 | rosarito
# Processing Record 18 of Set 17 | tiksi
# Processing Record 19 of Set 17 | ambilobe
# Processing Record 20 of Set 17 | saint-philippe
# Processing Record 21 of Set 17 | hobart
# Processing Record 22 of Set 17 | nome
# Processing Record 23 of Set 17 | bakchar
# Processing Record 24 of Set 17 | jiazi
# Processing Record 25 of Set 17 | aksarka
# Processing Record 26 of Set 17 | ilulissat
# Processing Record 27 of Set 17 | faanui
# Processing Record 28 of Set 17 | puerto ayora
# Processing Record 29 of Set 17 | sao filipe
# Processing Record 30 of Set 17 | souillac
# Processing Record 31 of Set 17 | makakilo city
# Processing Record 32 of Set 17 | xining
# Processing Record 33 of Set 17 | monduli
# Processing Record 34 of Set 17 | ponta do sol
# Processing Record 35 of Set 17 | klaksvik
# Processing Record 36 of Set 17 | nishihara
# Processing Record 37 of Set 17 | talnakh
# Processing Record 38 of Set 17 | hajnowka
# Processing Record 39 of Set 17 | khon buri
# Processing Record 40 of Set 17 | vaitupu
# City not found. Skipping...
# Processing Record 41 of Set 17 | tura
# Processing Record 42 of Set 17 | ginir
# Processing Record 43 of Set 17 | castro
# Processing Record 44 of Set 17 | khatanga
# Processing Record 45 of Set 17 | korla
# Processing Record 46 of Set 17 | new norfolk
# Processing Record 47 of Set 17 | cayenne
# Processing Record 48 of Set 17 | chuy
# Processing Record 49 of Set 17 | ust-kut
# Processing Record 50 of Set 17 | batticaloa
# Processing Record 1 of Set 18 | nikolskoye
# Processing Record 2 of Set 18 | okhotsk
# Processing Record 3 of Set 18 | anadyr
# Processing Record 4 of Set 18 | tuatapere
# Processing Record 5 of Set 18 | martil
# Processing Record 6 of Set 18 | dicabisagan
# Processing Record 7 of Set 18 | yulara
# Processing Record 8 of Set 18 | roma
# Processing Record 9 of Set 18 | north bend
# Processing Record 10 of Set 18 | springdale
# Processing Record 11 of Set 18 | palabuhanratu
# City not found. Skipping...
# Processing Record 12 of Set 18 | pemangkat
# Processing Record 13 of Set 18 | abu jubayhah
# City not found. Skipping...
# Processing Record 14 of Set 18 | balkanabat
# Processing Record 15 of Set 18 | te anau
# Processing Record 16 of Set 18 | kudahuvadhoo
# Processing Record 17 of Set 18 | hilo
# Processing Record 18 of Set 18 | cockburn harbour
# City not found. Skipping...
# Processing Record 19 of Set 18 | tuktoyaktuk
# Processing Record 20 of Set 18 | belmonte
# Processing Record 21 of Set 18 | amapa
# Processing Record 22 of Set 18 | mandalgovi
# Processing Record 23 of Set 18 | constitucion
# Processing Record 24 of Set 18 | talaya
# Processing Record 25 of Set 18 | tumannyy
# City not found. Skipping...
# Processing Record 26 of Set 18 | almaznyy
# Processing Record 27 of Set 18 | saskylakh
# Processing Record 28 of Set 18 | pemba
# Processing Record 29 of Set 18 | lebu
# Processing Record 30 of Set 18 | belushya guba
# City not found. Skipping...
# Processing Record 31 of Set 18 | port elizabeth
# Processing Record 32 of Set 18 | bredasdorp
# Processing Record 33 of Set 18 | lavumisa
# Processing Record 34 of Set 18 | kamenskoye
# City not found. Skipping...
# Processing Record 35 of Set 18 | tasiilaq
# Processing Record 36 of Set 18 | honiara
# Processing Record 37 of Set 18 | bonthe
# Processing Record 38 of Set 18 | wawa
# Processing Record 39 of Set 18 | keetmanshoop
# Processing Record 40 of Set 18 | nokaneng
# Processing Record 41 of Set 18 | marsh harbour
# Processing Record 42 of Set 18 | airai
# Processing Record 43 of Set 18 | lompoc
# Processing Record 44 of Set 18 | durazno
# Processing Record 45 of Set 18 | praia da vitoria
# Processing Record 46 of Set 18 | hithadhoo
# Processing Record 47 of Set 18 | sawtell
# Processing Record 48 of Set 18 | pimentel
# Processing Record 49 of Set 18 | tornio
# Processing Record 50 of Set 18 | vung tau
# Processing Record 1 of Set 19 | wewak
# Processing Record 2 of Set 19 | sentyabrskiy
# City not found. Skipping...
# Processing Record 3 of Set 19 | pangai
# Processing Record 4 of Set 19 | bambous virieux
# Processing Record 5 of Set 19 | lagoa
# Processing Record 6 of Set 19 | mahebourg
# Processing Record 7 of Set 19 | namie
# Processing Record 8 of Set 19 | yellowknife
# Processing Record 9 of Set 19 | torbay
# Processing Record 10 of Set 19 | quelimane
# Processing Record 11 of Set 19 | bengkulu
# Processing Record 12 of Set 19 | yuzawa
# Processing Record 13 of Set 19 | sorong
# Processing Record 14 of Set 19 | cherskiy
# Processing Record 15 of Set 19 | balykshi
# Processing Record 16 of Set 19 | tazmalt
# Processing Record 17 of Set 19 | geraldton
# Processing Record 18 of Set 19 | provideniya
# Processing Record 19 of Set 19 | ribeira grande
# Processing Record 20 of Set 19 | fortuna
# Processing Record 21 of Set 19 | mareeba
# Processing Record 22 of Set 19 | kuche
# City not found. Skipping...
# Processing Record 23 of Set 19 | roald
# Processing Record 24 of Set 19 | port-cartier
# Processing Record 25 of Set 19 | flinders
# Processing Record 26 of Set 19 | kozluk
# Processing Record 27 of Set 19 | iberia
# Processing Record 28 of Set 19 | luena
# Processing Record 29 of Set 19 | khuzhir
# Processing Record 30 of Set 19 | amalapuram
# Processing Record 31 of Set 19 | saldanha
# Processing Record 32 of Set 19 | tikhvin
# Processing Record 33 of Set 19 | alamosa
# Processing Record 34 of Set 19 | hlobyne
# Processing Record 35 of Set 19 | sitka
# Processing Record 36 of Set 19 | las cruces
# Processing Record 37 of Set 19 | hasaki
# Processing Record 38 of Set 19 | skibbereen
# Processing Record 39 of Set 19 | firminy
# Processing Record 40 of Set 19 | puerto escondido
# Processing Record 41 of Set 19 | clovis
# Processing Record 42 of Set 19 | lucapa
# Processing Record 43 of Set 19 | melilla
# Processing Record 44 of Set 19 | verkhnyaya inta
# Processing Record 45 of Set 19 | dunedin
# Processing Record 46 of Set 19 | dingle
# Processing Record 47 of Set 19 | high level
# Processing Record 48 of Set 19 | taltal
# Processing Record 49 of Set 19 | imeni poliny osipenko
# Processing Record 50 of Set 19 | saurimo
# Processing Record 1 of Set 20 | thesprotikon
# Processing Record 2 of Set 20 | guerrero negro
# Processing Record 3 of Set 20 | katsuura
# Processing Record 4 of Set 20 | abu samrah
# Processing Record 5 of Set 20 | pando
# Processing Record 6 of Set 20 | axim
# Processing Record 7 of Set 20 | domat
# Processing Record 8 of Set 20 | kloulklubed
# Processing Record 9 of Set 20 | chokurdakh
# Processing Record 10 of Set 20 | cabras
# Processing Record 11 of Set 20 | attawapiskat
# City not found. Skipping...
# Processing Record 12 of Set 20 | temaraia
# City not found. Skipping...
# Processing Record 13 of Set 20 | mayo
# Processing Record 14 of Set 20 | aklavik
# Processing Record 15 of Set 20 | shreveport
# Processing Record 16 of Set 20 | adre
# Processing Record 17 of Set 20 | launceston
# Processing Record 18 of Set 20 | nouadhibou
# Processing Record 19 of Set 20 | songea
# Processing Record 20 of Set 20 | tucurui
# Processing Record 21 of Set 20 | joinville
# Processing Record 22 of Set 20 | general roca
# Processing Record 23 of Set 20 | coahuayana
# Processing Record 24 of Set 20 | luderitz
# Processing Record 25 of Set 20 | pacov
# Processing Record 26 of Set 20 | arraial do cabo
# Processing Record 27 of Set 20 | acari
# Processing Record 28 of Set 20 | carnarvon
# Processing Record 29 of Set 20 | maniitsoq
# Processing Record 30 of Set 20 | samarai
# Processing Record 31 of Set 20 | walvis bay
# Processing Record 32 of Set 20 | warqla
# City not found. Skipping...
# Processing Record 33 of Set 20 | dali
# Processing Record 34 of Set 20 | san patricio
# Processing Record 35 of Set 20 | chaozhou
# Processing Record 36 of Set 20 | san cristobal
# Processing Record 37 of Set 20 | esperance
# Processing Record 38 of Set 20 | kafanchan
# Processing Record 39 of Set 20 | karmana
# City not found. Skipping...
# Processing Record 40 of Set 20 | hobyo
# Processing Record 41 of Set 20 | bur gabo
# City not found. Skipping...
# Processing Record 42 of Set 20 | ketchikan
# Processing Record 43 of Set 20 | ibra
# Processing Record 44 of Set 20 | tabialan
# City not found. Skipping...
# Processing Record 45 of Set 20 | saint george
# Processing Record 46 of Set 20 | riosucio
# Processing Record 47 of Set 20 | angra
# City not found. Skipping...
# Processing Record 48 of Set 20 | chara
# Processing Record 49 of Set 20 | petushki
# Processing Record 50 of Set 20 | chagda
# City not found. Skipping...
# Processing Record 1 of Set 21 | vilyuysk
# Processing Record 2 of Set 21 | sahrak
# City not found. Skipping...
# Processing Record 3 of Set 21 | skalistyy
# City not found. Skipping...
# Processing Record 4 of Set 21 | bereda
# Processing Record 5 of Set 21 | zhoucheng
# Processing Record 6 of Set 21 | mana
# Processing Record 7 of Set 21 | yaan
# Processing Record 8 of Set 21 | nouakchott
# Processing Record 9 of Set 21 | ndele
# Processing Record 10 of Set 21 | grajau
# Processing Record 11 of Set 21 | ipixuna
# Processing Record 12 of Set 21 | lata
# Processing Record 13 of Set 21 | kyshtovka
# Processing Record 14 of Set 21 | jambusar
# Processing Record 15 of Set 21 | along
# Processing Record 16 of Set 21 | ewa beach
# Processing Record 17 of Set 21 | macenta
# Processing Record 18 of Set 21 | komsomolskiy
# Processing Record 19 of Set 21 | kapurthala
# Processing Record 20 of Set 21 | saleaula
# City not found. Skipping...
# Processing Record 21 of Set 21 | newport
# Processing Record 22 of Set 21 | boma
# Processing Record 23 of Set 21 | nizhneyansk
# City not found. Skipping...
# Processing Record 24 of Set 21 | road town
# Processing Record 25 of Set 21 | idlib
# Processing Record 26 of Set 21 | tessalit
# Processing Record 27 of Set 21 | verkhnevilyuysk
# Processing Record 28 of Set 21 | kajaani
# Processing Record 29 of Set 21 | tanete
# Processing Record 30 of Set 21 | hambantota
# Processing Record 31 of Set 21 | victoria
# Processing Record 32 of Set 21 | mys shmidta
# City not found. Skipping...
# Processing Record 33 of Set 21 | mocambique
# City not found. Skipping...
# Processing Record 34 of Set 21 | warri
# Processing Record 35 of Set 21 | mafinga
# Processing Record 36 of Set 21 | narsaq
# Processing Record 37 of Set 21 | lahan
# Processing Record 38 of Set 21 | iquique
# Processing Record 39 of Set 21 | kyren
# Processing Record 40 of Set 21 | paamiut
# Processing Record 41 of Set 21 | hovd
# Processing Record 42 of Set 21 | saint-francois
# Processing Record 43 of Set 21 | sioux lookout
# Processing Record 44 of Set 21 | paita
# Processing Record 45 of Set 21 | zhigansk
# Processing Record 46 of Set 21 | hermiston
# Processing Record 47 of Set 21 | olafsvik
# Processing Record 48 of Set 21 | ilo
# Processing Record 49 of Set 21 | canala
# Processing Record 50 of Set 21 | kahului
# Processing Record 1 of Set 22 | urdzhar
# City not found. Skipping...
# Processing Record 2 of Set 22 | suntar
# Processing Record 3 of Set 22 | tual
# Processing Record 4 of Set 22 | padang
# Processing Record 5 of Set 22 | dudinka
# Processing Record 6 of Set 22 | bakel
# Processing Record 7 of Set 22 | chama
# Processing Record 8 of Set 22 | kavieng
# Processing Record 9 of Set 22 | ballina
# Processing Record 10 of Set 22 | ndende
# Processing Record 11 of Set 22 | galle
# Processing Record 12 of Set 22 | sedniv
# Processing Record 13 of Set 22 | ayagoz
# Processing Record 14 of Set 22 | barra patuca
# Processing Record 15 of Set 22 | kawhia
# Processing Record 16 of Set 22 | saint anthony
# Processing Record 17 of Set 22 | shubarkuduk
# Processing Record 18 of Set 22 | port hedland
# Processing Record 19 of Set 22 | mount gambier
# Processing Record 20 of Set 22 | aguimes
# Processing Record 21 of Set 22 | alofi
# Processing Record 22 of Set 22 | itupiranga
# Processing Record 23 of Set 22 | karpathos
# Processing Record 24 of Set 22 | koslan
# Processing Record 25 of Set 22 | batagay-alyta
# Processing Record 26 of Set 22 | arecibo
# Processing Record 27 of Set 22 | saint-georges
# Processing Record 28 of Set 22 | hay river
# Processing Record 29 of Set 22 | codrington
# Processing Record 30 of Set 22 | puerto el triunfo
# Processing Record 31 of Set 22 | doha
# Processing Record 32 of Set 22 | colac
# Processing Record 33 of Set 22 | alotau
# City not found. Skipping...
# Processing Record 34 of Set 22 | vanimo
# Processing Record 35 of Set 22 | parana
# Processing Record 36 of Set 22 | armidale
# Processing Record 37 of Set 22 | arenapolis
# Processing Record 38 of Set 22 | bowen
# Processing Record 39 of Set 22 | west lorne
# Processing Record 40 of Set 22 | taoudenni
# Processing Record 41 of Set 22 | turayf
# Processing Record 42 of Set 22 | salinopolis
# Processing Record 43 of Set 22 | chegem
# Processing Record 44 of Set 22 | cockburn town
# Processing Record 45 of Set 22 | nakhon phanom
# Processing Record 46 of Set 22 | grootfontein
# Processing Record 47 of Set 22 | fairbanks
# Processing Record 48 of Set 22 | dorado
# Processing Record 49 of Set 22 | teluknaga
# Processing Record 50 of Set 22 | kaitangata
# Processing Record 1 of Set 23 | grand river south east
# City not found. Skipping...
# Processing Record 2 of Set 23 | port lincoln
# Processing Record 3 of Set 23 | egvekinot
# Processing Record 4 of Set 23 | natchitoches
# Processing Record 5 of Set 23 | payo
# Processing Record 6 of Set 23 | coihaique
# Processing Record 7 of Set 23 | chingirlau
# Processing Record 8 of Set 23 | rawannawi
# City not found. Skipping...
# Processing Record 9 of Set 23 | beringovskiy
# Processing Record 10 of Set 23 | puerto colombia
# Processing Record 11 of Set 23 | gurskoye
# City not found. Skipping...
# Processing Record 12 of Set 23 | waikuku
# Processing Record 13 of Set 23 | clarence town
# Processing Record 14 of Set 23 | vestmanna
# Processing Record 15 of Set 23 | half moon bay
# Processing Record 16 of Set 23 | bonavista
# Processing Record 17 of Set 23 | acaponeta
# Processing Record 18 of Set 23 | medina del campo
# Processing Record 19 of Set 23 | lac du bonnet
# Processing Record 20 of Set 23 | rabo de peixe
# Processing Record 21 of Set 23 | mayya
# Processing Record 22 of Set 23 | wanning
# Processing Record 23 of Set 23 | cap malheureux
# Processing Record 24 of Set 23 | vangaindrano
# Processing Record 25 of Set 23 | hofn
# Processing Record 26 of Set 23 | eyl
# Processing Record 27 of Set 23 | saint-augustin
# Processing Record 28 of Set 23 | lorengau
# Processing Record 29 of Set 23 | etah
# Processing Record 30 of Set 23 | juneau
# Processing Record 31 of Set 23 | kommunar
# Processing Record 32 of Set 23 | senador canedo
# Processing Record 33 of Set 23 | mae sai
# Processing Record 34 of Set 23 | nicosia
# Processing Record 35 of Set 23 | kidodi
# Processing Record 36 of Set 23 | kalemie
# Processing Record 37 of Set 23 | aykhal
# Processing Record 38 of Set 23 | la primavera
# Processing Record 39 of Set 23 | balimo
# City not found. Skipping...
# Processing Record 40 of Set 23 | carutapera
# Processing Record 41 of Set 23 | gornoye loo
# Processing Record 42 of Set 23 | adrar
# Processing Record 43 of Set 23 | harlingen
# Processing Record 44 of Set 23 | srednekolymsk
# Processing Record 45 of Set 23 | las vegas
# Processing Record 46 of Set 23 | ardmore
# Processing Record 47 of Set 23 | kwinana
# Processing Record 48 of Set 23 | lavrentiya
# Processing Record 49 of Set 23 | hailar
# Processing Record 50 of Set 23 | meulaboh
# Processing Record 1 of Set 24 | parkes
# Processing Record 2 of Set 24 | chapada dos guimaraes
# Processing Record 3 of Set 24 | tupancireta
# Processing Record 4 of Set 24 | naryan-mar
# Processing Record 5 of Set 24 | karkaralinsk
# City not found. Skipping...
# Processing Record 6 of Set 24 | mayumba
# Processing Record 7 of Set 24 | baruun-urt
# Processing Record 8 of Set 24 | panuco
# Processing Record 9 of Set 24 | bapatla
# Processing Record 10 of Set 24 | karratha
# Processing Record 11 of Set 24 | beloha
# Processing Record 12 of Set 24 | samusu
# City not found. Skipping...
# Processing Record 13 of Set 24 | manggar
# Processing Record 14 of Set 24 | umzimvubu
# City not found. Skipping...
# Processing Record 15 of Set 24 | tabiauea
# City not found. Skipping...
# Processing Record 16 of Set 24 | vredendal
# Processing Record 17 of Set 24 | pecos
# Processing Record 18 of Set 24 | saint-joseph
# Processing Record 19 of Set 24 | trairi
# Processing Record 20 of Set 24 | mayari
# City not found. Skipping...
# Processing Record 21 of Set 24 | tahta
# Processing Record 22 of Set 24 | lashio
# Processing Record 23 of Set 24 | red bluff
# Processing Record 24 of Set 24 | danielskuil
# Processing Record 25 of Set 24 | izumo
# Processing Record 26 of Set 24 | asau
# Processing Record 27 of Set 24 | casper
# Processing Record 28 of Set 24 | bilibino
# Processing Record 29 of Set 24 | lluta
# Processing Record 30 of Set 24 | antequera
# Processing Record 31 of Set 24 | louga
# Processing Record 32 of Set 24 | hervey bay
# Processing Record 33 of Set 24 | tsihombe
# City not found. Skipping...
# Processing Record 34 of Set 24 | teya
# Processing Record 35 of Set 24 | tuy hoa
# Processing Record 36 of Set 24 | funadhoo
# Processing Record 37 of Set 24 | kieta
# Processing Record 38 of Set 24 | maceio
# Processing Record 39 of Set 24 | mount isa
# Processing Record 40 of Set 24 | victoria point
# Processing Record 41 of Set 24 | barabai
# Processing Record 42 of Set 24 | merrill
# Processing Record 43 of Set 24 | ancud
# Processing Record 44 of Set 24 | porto novo
# Processing Record 45 of Set 24 | omboue
# Processing Record 46 of Set 24 | namatanai
# Processing Record 47 of Set 24 | machhlishahr
# Processing Record 48 of Set 24 | santa cruz
# Processing Record 49 of Set 24 | dieppe
# Processing Record 50 of Set 24 | maragogi
# Processing Record 1 of Set 25 | dedovichi
# Processing Record 2 of Set 25 | san quintin
# Processing Record 3 of Set 25 | luwuk
# Processing Record 4 of Set 25 | rocha
# Processing Record 5 of Set 25 | kochinda
# Processing Record 6 of Set 25 | pyaozerskiy
# Processing Record 7 of Set 25 | mackay
# Processing Record 8 of Set 25 | melfort
# Processing Record 9 of Set 25 | marv dasht
# City not found. Skipping...
# Processing Record 10 of Set 25 | pevek
# Processing Record 11 of Set 25 | nantucket
# Processing Record 12 of Set 25 | moosomin
# Processing Record 13 of Set 25 | butwal
# Processing Record 14 of Set 25 | faya
# Processing Record 15 of Set 25 | chipaque
# Processing Record 16 of Set 25 | auki
# Processing Record 17 of Set 25 | kayes
# Processing Record 18 of Set 25 | namibe
# Processing Record 19 of Set 25 | evensk
# Processing Record 20 of Set 25 | port blair
# Processing Record 21 of Set 25 | beeville
# Processing Record 22 of Set 25 | skagastrond
# City not found. Skipping...
# Processing Record 23 of Set 25 | tateyama
# Processing Record 24 of Set 25 | chipinge
# Processing Record 25 of Set 25 | ahipara
# Processing Record 26 of Set 25 | bow island
# Processing Record 27 of Set 25 | semirom
# Processing Record 28 of Set 25 | lujiang
# Processing Record 29 of Set 25 | marawi
# Processing Record 30 of Set 25 | cagayan de tawi-tawi
# City not found. Skipping...
# Processing Record 31 of Set 25 | beira
# Processing Record 32 of Set 25 | kodinsk
# Processing Record 33 of Set 25 | isla vista
# Processing Record 34 of Set 25 | lakatoro
# Processing Record 35 of Set 25 | vila franca do campo
# Processing Record 36 of Set 25 | karauli
# Processing Record 37 of Set 25 | jalu
# Processing Record 38 of Set 25 | gorno-chuyskiy
# City not found. Skipping...
# Processing Record 39 of Set 25 | pechenga
# Processing Record 40 of Set 25 | simao
# Processing Record 41 of Set 25 | zaraza
# Processing Record 42 of Set 25 | tabou
# Processing Record 43 of Set 25 | pousat
# City not found. Skipping...
# Processing Record 44 of Set 25 | clyde river
# Processing Record 45 of Set 25 | chardara
# Processing Record 46 of Set 25 | shingu
# Processing Record 47 of Set 25 | rudbar
# Processing Record 48 of Set 25 | laguna
# Processing Record 49 of Set 25 | uthal
# Processing Record 50 of Set 25 | great yarmouth
# Processing Record 1 of Set 26 | nuuk
# Processing Record 2 of Set 26 | lolua
# City not found. Skipping...
# Processing Record 3 of Set 26 | rafai
# Processing Record 4 of Set 26 | turbat
# Processing Record 5 of Set 26 | kovernino
# Processing Record 6 of Set 26 | teknaf
# Processing Record 7 of Set 26 | saint-ambroise
# Processing Record 8 of Set 26 | lazurne
# Processing Record 9 of Set 26 | qui nhon
# Processing Record 10 of Set 26 | slupsk
# Processing Record 11 of Set 26 | nizhnyaya tavda
# Processing Record 12 of Set 26 | margate
# Processing Record 13 of Set 26 | oktyabrskoye
# Processing Record 14 of Set 26 | kirando
# Processing Record 15 of Set 26 | hammerfest
# Processing Record 16 of Set 26 | serenje
# Processing Record 17 of Set 26 | lumeje
# Processing Record 18 of Set 26 | ust-koksa
# Processing Record 19 of Set 26 | bathsheba
# Processing Record 20 of Set 26 | fuengirola
# Processing Record 21 of Set 26 | leningradskiy
# Processing Record 22 of Set 26 | kruisfontein
# Processing Record 23 of Set 26 | salalah
# Processing Record 24 of Set 26 | cam ranh
# Processing Record 25 of Set 26 | port shepstone
# Processing Record 26 of Set 26 | svetlyy
# Processing Record 27 of Set 26 | urumqi
# Processing Record 28 of Set 26 | la paz
# Processing Record 29 of Set 26 | rongcheng
# Processing Record 30 of Set 26 | portland
# Processing Record 31 of Set 26 | abu dhabi
# Processing Record 32 of Set 26 | vadlapudi
# Processing Record 33 of Set 26 | ambunti
# Processing Record 34 of Set 26 | martapura
# Processing Record 35 of Set 26 | korem
# Processing Record 36 of Set 26 | vila velha
# Processing Record 37 of Set 26 | terrace
# Processing Record 38 of Set 26 | hualmay
# Processing Record 39 of Set 26 | sorvag
# City not found. Skipping...
# Processing Record 40 of Set 26 | mozarlandia
# Processing Record 41 of Set 26 | wukari
# Processing Record 42 of Set 26 | necochea
# Processing Record 43 of Set 26 | bintulu
# Processing Record 44 of Set 26 | kang
# Processing Record 45 of Set 26 | albert lea
# Processing Record 46 of Set 26 | burica
# City not found. Skipping...
# Processing Record 47 of Set 26 | krasnousolskiy
# City not found. Skipping...
# Processing Record 48 of Set 26 | ruwi
# Processing Record 49 of Set 26 | solnechnyy
# Processing Record 50 of Set 26 | muisne
# Processing Record 1 of Set 27 | port townsend
# Processing Record 2 of Set 27 | kongolo
# Processing Record 3 of Set 27 | uruzgan
# Processing Record 4 of Set 27 | mahroni
# Processing Record 5 of Set 27 | yanam
# Processing Record 6 of Set 27 | vrangel
# Processing Record 7 of Set 27 | weinan
# Processing Record 8 of Set 27 | ambovombe
# Processing Record 9 of Set 27 | ayan
# Processing Record 10 of Set 27 | iqaluit
# Processing Record 11 of Set 27 | ust-maya
# Processing Record 12 of Set 27 | san jose
# Processing Record 13 of Set 27 | rudnogorsk
# Processing Record 14 of Set 27 | pingliang
# Processing Record 15 of Set 27 | naze
# Processing Record 16 of Set 27 | kawalu
# Processing Record 17 of Set 27 | kirksville
# Processing Record 18 of Set 27 | dogondoutchi
# Processing Record 19 of Set 27 | dezful
# Processing Record 20 of Set 27 | buariki
# City not found. Skipping...
# Processing Record 21 of Set 27 | piryetos
# City not found. Skipping...
# Processing Record 22 of Set 27 | ambulu
# Processing Record 23 of Set 27 | mansehra
# Processing Record 24 of Set 27 | mabaruma
# Processing Record 25 of Set 27 | blatna
# Processing Record 26 of Set 27 | vilhena
# Processing Record 27 of Set 27 | xai-xai
# Processing Record 28 of Set 27 | bentiu
# Processing Record 29 of Set 27 | mpongwe
# Processing Record 30 of Set 27 | dire
# Processing Record 31 of Set 27 | talcahuano
# Processing Record 32 of Set 27 | sao joao da barra
# Processing Record 33 of Set 27 | skovorodino
# Processing Record 34 of Set 27 | vestmannaeyjar
# Processing Record 35 of Set 27 | khorinsk
# Processing Record 36 of Set 27 | katangli
# Processing Record 37 of Set 27 | bilma
# Processing Record 38 of Set 27 | ascension
# Processing Record 39 of Set 27 | byron bay
# Processing Record 40 of Set 27 | guilin
# Processing Record 41 of Set 27 | sheopur
# Processing Record 42 of Set 27 | sinnamary
# Processing Record 43 of Set 27 | bolungarvik
# City not found. Skipping...
# Processing Record 44 of Set 27 | sao jose do belmonte
# Processing Record 45 of Set 27 | kandrian
# Processing Record 46 of Set 27 | tripoli
# Processing Record 47 of Set 27 | machico
# Processing Record 48 of Set 27 | karaul
# City not found. Skipping...
# Processing Record 49 of Set 27 | bainbridge
# Processing Record 50 of Set 27 | barahona
# Processing Record 1 of Set 28 | rapar
# Processing Record 2 of Set 28 | tarudant
# City not found. Skipping...
# Processing Record 3 of Set 28 | yanan
# City not found. Skipping...
# Processing Record 4 of Set 28 | kununurra
# Processing Record 5 of Set 28 | natal
# Processing Record 6 of Set 28 | dvinskoy
# Processing Record 7 of Set 28 | ixtapa
# Processing Record 8 of Set 28 | padilla
# Processing Record 9 of Set 28 | ust-tsilma
# Processing Record 10 of Set 28 | shieli
# Processing Record 11 of Set 28 | sierra vista
# Processing Record 12 of Set 28 | edd
# Processing Record 13 of Set 28 | cururupu
# Processing Record 14 of Set 28 | gat
# Processing Record 15 of Set 28 | gamba
# Processing Record 16 of Set 28 | teguldet
# Processing Record 17 of Set 28 | yerbogachen
# Processing Record 18 of Set 28 | oum hadjer
# Processing Record 19 of Set 28 | staryy nadym
# Processing Record 20 of Set 28 | kidal
# Processing Record 21 of Set 28 | bababe
# City not found. Skipping...
# Processing Record 22 of Set 28 | redding
# Processing Record 23 of Set 28 | pundaguitan
# Processing Record 24 of Set 28 | lakes entrance
# Processing Record 25 of Set 28 | gazanjyk
# Processing Record 26 of Set 28 | taunggyi
# Processing Record 27 of Set 28 | alberton
# Processing Record 28 of Set 28 | hokitika
# Processing Record 29 of Set 28 | don benito
# Processing Record 30 of Set 28 | kanniyakumari
# Processing Record 31 of Set 28 | kainantu
# Processing Record 32 of Set 28 | nanortalik
# Processing Record 33 of Set 28 | kawana waters
# City not found. Skipping...
# Processing Record 34 of Set 28 | san remo
# Processing Record 35 of Set 28 | zhuanghe
# Processing Record 36 of Set 28 | elko
# Processing Record 37 of Set 28 | fort saint james
# Processing Record 38 of Set 28 | mocuba
# Processing Record 39 of Set 28 | ostrovnoy
# Processing Record 40 of Set 28 | orgun
# City not found. Skipping...
# Processing Record 41 of Set 28 | dalinghe
# City not found. Skipping...
# Processing Record 42 of Set 28 | aksum
# Processing Record 43 of Set 28 | menomonie
# Processing Record 44 of Set 28 | sur
# Processing Record 45 of Set 28 | kamsack
# Processing Record 46 of Set 28 | itarema
# Processing Record 47 of Set 28 | dickinson
# Processing Record 48 of Set 28 | alyangula
# Processing Record 49 of Set 28 | chapais
# Processing Record 50 of Set 28 | vydrino
# Processing Record 1 of Set 29 | dalnerechensk
# Processing Record 2 of Set 29 | herat
# Processing Record 3 of Set 29 | vanavara
# Processing Record 4 of Set 29 | norrkoping
# Processing Record 5 of Set 29 | seoul
# Processing Record 6 of Set 29 | kilindoni
# Processing Record 7 of Set 29 | pascagoula
# Processing Record 8 of Set 29 | tambul
# City not found. Skipping...
# Processing Record 9 of Set 29 | panguipulli
# Processing Record 10 of Set 29 | zyryanka
# Processing Record 11 of Set 29 | louisbourg
# City not found. Skipping...
# Processing Record 12 of Set 29 | lokosovo
# Processing Record 13 of Set 29 | minot
# Processing Record 14 of Set 29 | kokstad
# Processing Record 15 of Set 29 | flin flon
# Processing Record 16 of Set 29 | ust-ilimsk
# Processing Record 17 of Set 29 | trincomalee
# Processing Record 18 of Set 29 | grand gaube
# Processing Record 19 of Set 29 | aquiraz
# Processing Record 20 of Set 29 | halalo
# City not found. Skipping...
# Processing Record 21 of Set 29 | matara
# Processing Record 22 of Set 29 | nurota
# Processing Record 23 of Set 29 | goma
# Processing Record 24 of Set 29 | todos santos
# Processing Record 25 of Set 29 | khonuu
# City not found. Skipping...
# Processing Record 26 of Set 29 | mantes-la-ville
# Processing Record 27 of Set 29 | brae
# Processing Record 28 of Set 29 | daru
# Processing Record 29 of Set 29 | galgani
# City not found. Skipping...
# Processing Record 30 of Set 29 | maarianhamina
# Processing Record 31 of Set 29 | pisco
# Processing Record 32 of Set 29 | sangod
# Processing Record 33 of Set 29 | ningan
# City not found. Skipping...
# Processing Record 34 of Set 29 | pacific grove
# Processing Record 35 of Set 29 | barbacoas
# Processing Record 36 of Set 29 | tiznit
# Processing Record 37 of Set 29 | viedma
# Processing Record 38 of Set 29 | puerto narino
# Processing Record 39 of Set 29 | canico
# Processing Record 40 of Set 29 | mersing
# Processing Record 41 of Set 29 | nabire
# Processing Record 42 of Set 29 | sinzig
# Processing Record 43 of Set 29 | usinsk
# Processing Record 44 of Set 29 | zlatoustovsk
# City not found. Skipping...
# Processing Record 45 of Set 29 | vardo
# Processing Record 46 of Set 29 | sai buri
# Processing Record 47 of Set 29 | kavaratti
# Processing Record 48 of Set 29 | birjand
# Processing Record 49 of Set 29 | domoni
# Processing Record 50 of Set 29 | kegayli
# City not found. Skipping...
# Processing Record 1 of Set 30 | sataua
# City not found. Skipping...
# Processing Record 2 of Set 30 | touros
# Processing Record 3 of Set 30 | dongzhen
# Processing Record 4 of Set 30 | alexandria
# Processing Record 5 of Set 30 | malwan
# City not found. Skipping...
# Processing Record 6 of Set 30 | sangar
# Processing Record 7 of Set 30 | marzuq
# Processing Record 8 of Set 30 | ye
# City not found. Skipping...
# Processing Record 9 of Set 30 | ongwediva
# Processing Record 10 of Set 30 | doka
# Processing Record 11 of Set 30 | marcona
# City not found. Skipping...
# Processing Record 12 of Set 30 | bijapur
# Processing Record 13 of Set 30 | mugumu
# Processing Record 14 of Set 30 | moranbah
# Processing Record 15 of Set 30 | liverpool
# Processing Record 16 of Set 30 | envira
# Processing Record 17 of Set 30 | harper
# Processing Record 18 of Set 30 | port macquarie
# Processing Record 19 of Set 30 | batouri
# Processing Record 20 of Set 30 | remanso
# Processing Record 21 of Set 30 | princeton
# Processing Record 22 of Set 30 | tecoanapa
# Processing Record 23 of Set 30 | aranos
# Processing Record 24 of Set 30 | vostok
# Processing Record 25 of Set 30 | vao
# Processing Record 26 of Set 30 | pangkalanbuun
# Processing Record 27 of Set 30 | antofagasta
# Processing Record 28 of Set 30 | acapulco
# Processing Record 29 of Set 30 | nicoya
# Processing Record 30 of Set 30 | bubaque
# Processing Record 31 of Set 30 | horn lake
# Processing Record 32 of Set 30 | tirano
# Processing Record 33 of Set 30 | santa vitoria
# Processing Record 34 of Set 30 | labytnangi
# Processing Record 35 of Set 30 | buala
# Processing Record 36 of Set 30 | oranjestad
# Processing Record 37 of Set 30 | port augusta
# Processing Record 38 of Set 30 | tautira
# Processing Record 39 of Set 30 | point fortin
# Processing Record 40 of Set 30 | panlaitan
# Processing Record 41 of Set 30 | tukrah
# Processing Record 42 of Set 30 | stekolnyy
# City not found. Skipping...
# Processing Record 43 of Set 30 | oranjemund
# Processing Record 44 of Set 30 | hong gai
# Processing Record 45 of Set 30 | rodrigues alves
# Processing Record 46 of Set 30 | la plata
# Processing Record 47 of Set 30 | bredy
# Processing Record 48 of Set 30 | arlit
# Processing Record 49 of Set 30 | kamina
# Processing Record 50 of Set 30 | biak
# Processing Record 1 of Set 31 | matay
# Processing Record 2 of Set 31 | fort-shevchenko
# Processing Record 3 of Set 31 | nemuro
# Processing Record 4 of Set 31 | batemans bay
# -----------------------------
# Data Retrieval Complete
# -----------------------------

# %%
new_column_order = ["City", "Country", "Lat","Lng","Max Temp","Humidity", "Cloudiness", "Wind Speed", "Current Description"]
city_data_df=city_data_df[new_column_order]
city_data_df
# Out:
#                  City Country      Lat       Lng  Max Temp  Humidity  \
# 0               bluff      NZ -46.6000  168.3333     44.24        81
# 1              atuona      PF  -9.8000 -139.0333     79.90        73
# 2            plouzane      FR  48.3833   -4.6167     60.89        94
# 3         port alfred      ZA -33.5906   26.8910     68.32        49
# 4             ushuaia      AR -54.8000  -68.3000     38.86        81
# ...               ...     ...      ...       ...       ...       ...
# 1355             biak      ID  -0.9131  122.8766     76.35        81
# 1356            matay      EG  28.4190   30.7792     86.88        23
# 1357  fort-shevchenko      KZ  44.5086   50.2630     73.04        73
# 1358           nemuro      JP  43.3236  145.5750     54.10        93
# 1359     batemans bay      AU -35.7167  150.1833     52.20        66
#
#       Cloudiness  Wind Speed Current Description
# 0              3        6.85                 NaN
# 1             36       18.07                 NaN
# 2             90        4.61                 NaN
# 3             38        9.31                 NaN
# 4              0        3.44                 NaN
# ...          ...         ...                 ...
# 1355          28        4.50    scattered clouds
# 1356           0        7.47           clear sky
# 1357          78       11.54       broken clouds
# 1358         100       17.18     overcast clouds
# 1359          77        7.47       broken clouds
#
# [1360 rows x 9 columns]

# %%
# Create the output file (CSV).
output_data_file = "Weather_Database/WeatherPy_Database.csv"
# Export the City_Data into a CSV.
city_data_df.to_csv(output_data_file, index_label="City_ID")
